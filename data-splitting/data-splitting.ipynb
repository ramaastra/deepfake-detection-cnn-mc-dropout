# %% [markdown]
# # Dataset Splitting

# %% [markdown]
# This notebook is used to split [Celeb-DF-v2](https://github.com/yuezunli/celeb-deepfakeforensics), [DeeperForensics-1.0](https://github.com/EndlessSora/DeeperForensics-1.0), and [DFDC](https://www.kaggle.com/c/deepfake-detection-challenge) dataset into train, validation, and test sets for deepfake detection research purposes. The [600 sampled videos](https://github.com/ramaastra/deepfake-detection-cnn-mc-dropout/tree/main/data-sampling) from the three datasets are splitted each with a ratio of 70%, 10%, and 20% respectively.

# %%
import os
import random
import shutil
import pandas as pd

# %% [markdown]
# ## Define Dataset Path

# %% [markdown]
# ### Face Extracted Dataset Directory

# %%
CDF_DIR = "/mnt/e/samples/extracted/Celeb-DF-v2"
DF_DIR = "/mnt/e/samples/extracted/DeeperForensics-1.0"
DFDC_DIR = "/mnt/e/samples/extracted/DFDC"

# %% [markdown]
# ### Dataset Split Output Directory

# %%
CDF_OUTPUT_DIR = "/mnt/e/samples/split/Celeb-DF-v2"
DF_OUTPUT_DIR = "/mnt/e/samples/split/DeeperForensics-1.0"
DFDC_OUTPUT_DIR = "/mnt/e/samples/split/DFDC"

# %% [markdown]
# ### Dataset Sample List Filepath

# %%
CDF_SAMPLE_LIST = "../data-sampling/celeb-df-v2-list.csv"
DF_SAMPLE_LIST = "../data-sampling/deeperforensics-1.0-list.csv"
DFDC_SAMPLE_LIST = "../data-sampling/dfdc-list.csv"

# %% [markdown]
# ## Define Dataset Split Ratio

# %%
DATASET_SIZE = 200
NUM_LABELS = 2

TRAIN_RATIO = 0.7
VAL_RATIO = 0.1
TEST_RATIO = 0.2

# %%
train_size_per_label = int(DATASET_SIZE * TRAIN_RATIO / 2)
val_size_per_label = int(DATASET_SIZE * VAL_RATIO / 2)
test_size_per_label = int(DATASET_SIZE * TEST_RATIO / 2)

print(f"Train size per label\t: {train_size_per_label} video")
print(f"Val size per label\t: {val_size_per_label} video")
print(f"Test size per label\t: {test_size_per_label} video")
# Out:
# Train size per label	: 70 video
# Val size per label	: 10 video
# Test size per label	: 20 video

# %% [markdown]
# ## Load Dataset Sample List into Dataframe

# %%
cdf_list_df = pd.read_csv(CDF_SAMPLE_LIST)
df_list_df = pd.read_csv(DF_SAMPLE_LIST)
dfdc_list_df = pd.read_csv(DFDC_SAMPLE_LIST)

print("Dataframe example:")
cdf_list_df.head()
# Out:
# Dataframe example:
#                                              file     label
# 0   Celeb-DF-v2/Celeb-synthesis/id23_id3_0003.mp4  deepfake
# 1  Celeb-DF-v2/Celeb-synthesis/id53_id56_0009.mp4  deepfake
# 2  Celeb-DF-v2/Celeb-synthesis/id17_id26_0009.mp4  deepfake
# 3  Celeb-DF-v2/Celeb-synthesis/id54_id51_0008.mp4  deepfake
# 4  Celeb-DF-v2/Celeb-synthesis/id59_id60_0006.mp4  deepfake

# %% [markdown]
# ## Split the Dataset

# %%
def remove_sampled_data(data, sample):
    return [value for value in data if value not in sample]


def train_val_test_split(df):
    deepfakes = df[df["label"] == "deepfake"].get("file").values
    real_vids = df[df["label"] == "real"].get("file").values

    indices = range(len(df) // NUM_LABELS)

    # Take train sample
    train_indices = random.sample(indices, train_size_per_label)
    indices = remove_sampled_data(indices, train_indices)

    # Take validation sample
    val_indices = random.sample(indices, val_size_per_label)
    indices = remove_sampled_data(indices, val_indices)

    # Take test sample
    test_indices = random.sample(indices, test_size_per_label)
    indices = remove_sampled_data(indices, test_indices)

    train_deepfakes = [deepfakes[i] for i in train_indices]
    val_deepfakes = [deepfakes[i] for i in val_indices]
    test_deepfakes = [deepfakes[i] for i in test_indices]

    train_real_vids = [real_vids[i] for i in train_indices]
    val_real_vids = [real_vids[i] for i in val_indices]
    test_real_vids = [real_vids[i] for i in test_indices]

    data = {"file_id": [], "label": [], "split": []}

    # Add file ids to dict
    data["file_id"] += train_deepfakes + train_real_vids
    data["file_id"] += val_deepfakes + val_real_vids
    data["file_id"] += test_deepfakes + test_real_vids

    # Add labels to dict
    data["label"] += ["deepfake" for _ in range(len(train_deepfakes))]
    data["label"] += ["real" for _ in range(len(train_real_vids))]
    data["label"] += ["deepfake" for _ in range(len(val_deepfakes))]
    data["label"] += ["real" for _ in range(len(val_real_vids))]
    data["label"] += ["deepfake" for _ in range(len(test_deepfakes))]
    data["label"] += ["real" for _ in range(len(test_real_vids))]

    # Add split information to dict
    data["split"] += ["train" for _ in range(train_size_per_label * NUM_LABELS)]
    data["split"] += ["val" for _ in range(val_size_per_label * NUM_LABELS)]
    data["split"] += ["test" for _ in range(test_size_per_label * NUM_LABELS)]

    df = pd.DataFrame(data)
    return df

# %%
cdf_split = train_val_test_split(cdf_list_df)
df_split = train_val_test_split(df_list_df)
dfdc_split = train_val_test_split(dfdc_list_df)

print("Example of generated split list:")
cdf_split.head()
# Out:
# Example of generated split list:
#    Unnamed: 0                                         file_id     label  split
# 0           0   Celeb-DF-v2/Celeb-synthesis/id0_id16_0001.mp4  deepfake  train
# 1           1  Celeb-DF-v2/Celeb-synthesis/id55_id52_0008.mp4  deepfake  train
# 2           2  Celeb-DF-v2/Celeb-synthesis/id59_id60_0006.mp4  deepfake  train
# 3           3  Celeb-DF-v2/Celeb-synthesis/id48_id45_0008.mp4  deepfake  train
# 4           4  Celeb-DF-v2/Celeb-synthesis/id20_id29_0002.mp4  deepfake  train

# %% [markdown]
# ## Function to Extract File Id from Filepath

# %%
def get_file_id(filepath):
    filename = os.path.basename(filepath)

    # Remove filename extension
    file_id = os.path.splitext(filename)[0]

    return file_id

# %% [markdown]
# ## Function to Copy Data into Output Directory

# %%
def copy_data_to_split_dir(split_df, source_dir, target_dir):
    for row in split_df.values:
        filepath, label, split = row
        file_id = get_file_id(filepath)
        label_dirname = "Original" if label == "real" else "Deepfake"

        dataset_dir = os.path.join(source_dir, label_dirname)
        output_dir = os.path.join(target_dir, split.capitalize(), label_dirname)

        extracted_filenames = [
            filename
            for filename in os.listdir(dataset_dir)
            if file_id in filename.split("-")[0]
        ]

        print(f"Processing {file_id}")
        for filename in extracted_filenames:
            extracted_filepath = os.path.join(dataset_dir, filename)
            output_filepath = os.path.join(output_dir, filename)
            if os.path.isfile(extracted_filepath):
                shutil.copy(extracted_filepath, output_filepath)

        print("=> Successfully copied to the split directory\n")

# %% [markdown]
# ## Create a Copy of Splitted Celeb-DF-v2 Dataset

# %%
copy_data_to_split_dir(cdf_split, CDF_DIR, CDF_OUTPUT_DIR)
# Out:
# Processing id0_id16_0001
# => Successfully copied to the split directory
#
# Processing id55_id52_0008
# => Successfully copied to the split directory
#
# Processing id59_id60_0006
# => Successfully copied to the split directory
#
# Processing id48_id45_0008
# => Successfully copied to the split directory
#
# Processing id20_id29_0002
# => Successfully copied to the split directory
#
# Processing id61_id5_0009
# => Successfully copied to the split directory
#
# Processing id57_id52_0006
# => Successfully copied to the split directory
#
# Processing id29_id33_0006
# => Successfully copied to the split directory
#
# Processing id49_id52_0003
# => Successfully copied to the split directory
#
# Processing id13_id7_0008
# => Successfully copied to the split directory
#
# Processing id3_id1_0007
# => Successfully copied to the split directory
#
# Processing id51_id53_0005
# => Successfully copied to the split directory
#
# Processing id6_id9_0003
# => Successfully copied to the split directory
#
# Processing id32_id37_0000
# => Successfully copied to the split directory
#
# Processing id41_id42_0006
# => Successfully copied to the split directory
#
# Processing id19_id28_0002
# => Successfully copied to the split directory
#
# Processing id52_id58_0003
# => Successfully copied to the split directory
#
# Processing id33_id23_0006
# => Successfully copied to the split directory
#
# Processing id20_id0_0000
# => Successfully copied to the split directory
#
# Processing id3_id1_0001
# => Successfully copied to the split directory
#
# Processing id12_id7_0000
# => Successfully copied to the split directory
#
# Processing id53_id56_0009
# => Successfully copied to the split directory
#
# Processing id48_id47_0003
# => Successfully copied to the split directory
#
# Processing id49_id58_0006
# => Successfully copied to the split directory
#
# Processing id11_id7_0006
# => Successfully copied to the split directory
#
# Processing id53_id55_0007
# => Successfully copied to the split directory
#
# Processing id46_id41_0003
# => Successfully copied to the split directory
#
# Processing id8_id6_0002
# => Successfully copied to the split directory
#
# Processing id10_id12_0006
# => Successfully copied to the split directory
#
# Processing id41_id46_0002
# => Successfully copied to the split directory
#
# Processing id50_id49_0003
# => Successfully copied to the split directory
#
# Processing id40_id39_0001
# => Successfully copied to the split directory
#
# Processing id13_id7_0007
# => Successfully copied to the split directory
#
# Processing id0_id1_0000
# => Successfully copied to the split directory
#
# Processing id27_id22_0006
# => Successfully copied to the split directory
#
# Processing id13_id10_0014
# => Successfully copied to the split directory
#
# Processing id46_id45_0001
# => Successfully copied to the split directory
#
# Processing id54_id58_0007
# => Successfully copied to the split directory
#
# Processing id11_id7_0003
# => Successfully copied to the split directory
#
# Processing id51_id53_0004
# => Successfully copied to the split directory
#
# Processing id16_id9_0004
# => Successfully copied to the split directory
#
# Processing id29_id23_0002
# => Successfully copied to the split directory
#
# Processing id21_id24_0008
# => Successfully copied to the split directory
#
# Processing id54_id51_0008
# => Successfully copied to the split directory
#
# Processing id7_id13_0001
# => Successfully copied to the split directory
#
# Processing id49_id57_0008
# => Successfully copied to the split directory
#
# Processing id22_id20_0004
# => Successfully copied to the split directory
#
# Processing id47_id39_0005
# => Successfully copied to the split directory
#
# Processing id4_id20_0005
# => Successfully copied to the split directory
#
# Processing id23_id3_0005
# => Successfully copied to the split directory
#
# Processing id53_id54_0004
# => Successfully copied to the split directory
#
# Processing id16_id1_0007
# => Successfully copied to the split directory
#
# Processing id28_id29_0009
# => Successfully copied to the split directory
#
# Processing id20_id1_0007
# => Successfully copied to the split directory
#
# Processing id61_id60_0005
# => Successfully copied to the split directory
#
# Processing id45_id41_0000
# => Successfully copied to the split directory
#
# Processing id41_id47_0008
# => Successfully copied to the split directory
#
# Processing id42_id39_0000
# => Successfully copied to the split directory
#
# Processing id58_id52_0002
# => Successfully copied to the split directory
#
# Processing id53_id56_0005
# => Successfully copied to the split directory
#
# Processing id40_id48_0008
# => Successfully copied to the split directory
#
# Processing id4_id37_0000
# => Successfully copied to the split directory
#
# Processing id26_id37_0003
# => Successfully copied to the split directory
#
# Processing id24_id19_0003
# => Successfully copied to the split directory
#
# Processing id42_id40_0002
# => Successfully copied to the split directory
#
# Processing id25_id27_0008
# => Successfully copied to the split directory
#
# Processing id24_id21_0004
# => Successfully copied to the split directory
#
# Processing id2_id0_0006
# => Successfully copied to the split directory
#
# Processing id9_id0_0005
# => Successfully copied to the split directory
#
# Processing id41_id42_0009
# => Successfully copied to the split directory
#
# Processing id0_0001
# => Successfully copied to the split directory
#
# Processing id55_0008
# => Successfully copied to the split directory
#
# Processing id59_0006
# => Successfully copied to the split directory
#
# Processing id48_0008
# => Successfully copied to the split directory
#
# Processing id20_0002
# => Successfully copied to the split directory
#
# Processing id61_0009
# => Successfully copied to the split directory
#
# Processing id57_0006
# => Successfully copied to the split directory
#
# Processing id29_0006
# => Successfully copied to the split directory
#
# Processing id49_0003
# => Successfully copied to the split directory
#
# Processing id13_0008
# => Successfully copied to the split directory
#
# Processing id3_0007
# => Successfully copied to the split directory
#
# Processing id51_0005
# => Successfully copied to the split directory
#
# Processing id6_0003
# => Successfully copied to the split directory
#
# Processing id32_0000
# => Successfully copied to the split directory
#
# Processing id41_0006
# => Successfully copied to the split directory
#
# Processing id19_0002
# => Successfully copied to the split directory
#
# Processing id52_0003
# => Successfully copied to the split directory
#
# Processing id33_0006
# => Successfully copied to the split directory
#
# Processing id20_0000
# => Successfully copied to the split directory
#
# Processing id3_0001
# => Successfully copied to the split directory
#
# Processing id12_0000
# => Successfully copied to the split directory
#
# Processing id53_0009
# => Successfully copied to the split directory
#
# Processing id48_0003
# => Successfully copied to the split directory
#
# Processing id49_0006
# => Successfully copied to the split directory
#
# Processing id11_0006
# => Successfully copied to the split directory
#
# Processing id53_0007
# => Successfully copied to the split directory
#
# Processing id46_0003
# => Successfully copied to the split directory
#
# Processing id8_0002
# => Successfully copied to the split directory
#
# Processing id10_0006
# => Successfully copied to the split directory
#
# Processing id41_0002
# => Successfully copied to the split directory
#
# Processing id50_0003
# => Successfully copied to the split directory
#
# Processing id40_0001
# => Successfully copied to the split directory
#
# Processing id13_0007
# => Successfully copied to the split directory
#
# Processing id0_0000
# => Successfully copied to the split directory
#
# Processing id27_0006
# => Successfully copied to the split directory
#
# Processing id13_0014
# => Successfully copied to the split directory
#
# Processing id46_0001
# => Successfully copied to the split directory
#
# Processing id54_0007
# => Successfully copied to the split directory
#
# Processing id11_0003
# => Successfully copied to the split directory
#
# Processing id51_0004
# => Successfully copied to the split directory
#
# Processing id16_0004
# => Successfully copied to the split directory
#
# Processing id29_0002
# => Successfully copied to the split directory
#
# Processing id21_0008
# => Successfully copied to the split directory
#
# Processing id54_0008
# => Successfully copied to the split directory
#
# Processing id7_0001
# => Successfully copied to the split directory
#
# Processing id49_0008
# => Successfully copied to the split directory
#
# Processing id22_0004
# => Successfully copied to the split directory
#
# Processing id47_0005
# => Successfully copied to the split directory
#
# Processing id4_0005
# => Successfully copied to the split directory
#
# Processing id23_0005
# => Successfully copied to the split directory
#
# Processing id53_0004
# => Successfully copied to the split directory
#
# Processing id16_0007
# => Successfully copied to the split directory
#
# Processing id28_0009
# => Successfully copied to the split directory
#
# Processing id20_0007
# => Successfully copied to the split directory
#
# Processing id61_0005
# => Successfully copied to the split directory
#
# Processing id45_0000
# => Successfully copied to the split directory
#
# Processing id41_0008
# => Successfully copied to the split directory
#
# Processing id42_0000
# => Successfully copied to the split directory
#
# Processing id58_0002
# => Successfully copied to the split directory
#
# Processing id53_0005
# => Successfully copied to the split directory
#
# Processing id40_0008
# => Successfully copied to the split directory
#
# Processing id4_0000
# => Successfully copied to the split directory
#
# Processing id26_0003
# => Successfully copied to the split directory
#
# Processing id24_0003
# => Successfully copied to the split directory
#
# Processing id42_0002
# => Successfully copied to the split directory
#
# Processing id25_0008
# => Successfully copied to the split directory
#
# Processing id24_0004
# => Successfully copied to the split directory
#
# Processing id2_0006
# => Successfully copied to the split directory
#
# Processing id9_0005
# => Successfully copied to the split directory
#
# Processing id41_0009
# => Successfully copied to the split directory
#
# Processing id9_id3_0007
# => Successfully copied to the split directory
#
# Processing id48_id40_0005
# => Successfully copied to the split directory
#
# Processing id6_id21_0004
# => Successfully copied to the split directory
#
# Processing id39_id46_0006
# => Successfully copied to the split directory
#
# Processing id50_id56_0009
# => Successfully copied to the split directory
#
# Processing id19_id22_0004
# => Successfully copied to the split directory
#
# Processing id4_id21_0002
# => Successfully copied to the split directory
#
# Processing id23_id3_0003
# => Successfully copied to the split directory
#
# Processing id31_id34_0002
# => Successfully copied to the split directory
#
# Processing id33_id32_0004
# => Successfully copied to the split directory
#
# Processing id9_0007
# => Successfully copied to the split directory
#
# Processing id48_0005
# => Successfully copied to the split directory
#
# Processing id6_0004
# => Successfully copied to the split directory
#
# Processing id39_0006
# => Successfully copied to the split directory
#
# Processing id50_0009
# => Successfully copied to the split directory
#
# Processing id19_0004
# => Successfully copied to the split directory
#
# Processing id4_0002
# => Successfully copied to the split directory
#
# Processing id23_0003
# => Successfully copied to the split directory
#
# Processing id31_0002
# => Successfully copied to the split directory
#
# Processing id33_0004
# => Successfully copied to the split directory
#
# Processing id0_id6_0009
# => Successfully copied to the split directory
#
# Processing id25_id28_0000
# => Successfully copied to the split directory
#
# Processing id21_id17_0004
# => Successfully copied to the split directory
#
# Processing id57_id53_0008
# => Successfully copied to the split directory
#
# Processing id3_id16_0004
# => Successfully copied to the split directory
#
# Processing id58_id56_0001
# => Successfully copied to the split directory
#
# Processing id31_id26_0005
# => Successfully copied to the split directory
#
# Processing id28_id17_0008
# => Successfully copied to the split directory
#
# Processing id22_id24_0009
# => Successfully copied to the split directory
#
# Processing id17_id26_0009
# => Successfully copied to the split directory
#
# Processing id22_id27_0003
# => Successfully copied to the split directory
#
# Processing id25_id24_0002
# => Successfully copied to the split directory
#
# Processing id61_id5_0006
# => Successfully copied to the split directory
#
# Processing id32_id33_0003
# => Successfully copied to the split directory
#
# Processing id61_id60_0000
# => Successfully copied to the split directory
#
# Processing id7_id10_0003
# => Successfully copied to the split directory
#
# Processing id47_id45_0002
# => Successfully copied to the split directory
#
# Processing id17_id28_0006
# => Successfully copied to the split directory
#
# Processing id51_id57_0006
# => Successfully copied to the split directory
#
# Processing id32_id20_0005
# => Successfully copied to the split directory
#
# Processing id0_0009
# => Successfully copied to the split directory
#
# Processing id25_0000
# => Successfully copied to the split directory
#
# Processing id21_0004
# => Successfully copied to the split directory
#
# Processing id57_0008
# => Successfully copied to the split directory
#
# Processing id3_0004
# => Successfully copied to the split directory
#
# Processing id58_0001
# => Successfully copied to the split directory
#
# Processing id31_0005
# => Successfully copied to the split directory
#
# Processing id28_0008
# => Successfully copied to the split directory
#
# Processing id22_0009
# => Successfully copied to the split directory
#
# Processing id17_0009
# => Successfully copied to the split directory
#
# Processing id22_0003
# => Successfully copied to the split directory
#
# Processing id25_0002
# => Successfully copied to the split directory
#
# Processing id61_0006
# => Successfully copied to the split directory
#
# Processing id32_0003
# => Successfully copied to the split directory
#
# Processing id61_0000
# => Successfully copied to the split directory
#
# Processing id7_0003
# => Successfully copied to the split directory
#
# Processing id47_0002
# => Successfully copied to the split directory
#
# Processing id17_0006
# => Successfully copied to the split directory
#
# Processing id51_0006
# => Successfully copied to the split directory
#
# Processing id32_0005
# => Successfully copied to the split directory

# %% [markdown]
# ## Create a Copy of Splitted DeeperForensics-1.0 Dataset

# %%
copy_data_to_split_dir(df_split, DF_DIR, DF_OUTPUT_DIR)
# Out:
# Processing 902_M029
# => Successfully copied to the split directory
#
# Processing 979_M038
# => Successfully copied to the split directory
#
# Processing 416_M030
# => Successfully copied to the split directory
#
# Processing 771_W027
# => Successfully copied to the split directory
#
# Processing 876_M025
# => Successfully copied to the split directory
#
# Processing 890_W110
# => Successfully copied to the split directory
#
# Processing 537_W136
# => Successfully copied to the split directory
#
# Processing 358_M025
# => Successfully copied to the split directory
#
# Processing 469_W027
# => Successfully copied to the split directory
#
# Processing 487_W031
# => Successfully copied to the split directory
#
# Processing 017_W006
# => Successfully copied to the split directory
#
# Processing 360_W012
# => Successfully copied to the split directory
#
# Processing 584_M118
# => Successfully copied to the split directory
#
# Processing 912_M031
# => Successfully copied to the split directory
#
# Processing 024_M113
# => Successfully copied to the split directory
#
# Processing 767_M012
# => Successfully copied to the split directory
#
# Processing 598_W116
# => Successfully copied to the split directory
#
# Processing 955_M138
# => Successfully copied to the split directory
#
# Processing 707_M007
# => Successfully copied to the split directory
#
# Processing 039_M114
# => Successfully copied to the split directory
#
# Processing 177_W133
# => Successfully copied to the split directory
#
# Processing 374_M026
# => Successfully copied to the split directory
#
# Processing 582_M117
# => Successfully copied to the split directory
#
# Processing 286_M134
# => Successfully copied to the split directory
#
# Processing 759_W025
# => Successfully copied to the split directory
#
# Processing 265_W111
# => Successfully copied to the split directory
#
# Processing 218_M011
# => Successfully copied to the split directory
#
# Processing 472_W028
# => Successfully copied to the split directory
#
# Processing 180_M007
# => Successfully copied to the split directory
#
# Processing 941_W100
# => Successfully copied to the split directory
#
# Processing 885_W042
# => Successfully copied to the split directory
#
# Processing 682_M004
# => Successfully copied to the split directory
#
# Processing 727_M008
# => Successfully copied to the split directory
#
# Processing 365_M026
# => Successfully copied to the split directory
#
# Processing 836_W037
# => Successfully copied to the split directory
#
# Processing 607_W100
# => Successfully copied to the split directory
#
# Processing 174_W029
# => Successfully copied to the split directory
#
# Processing 371_W013
# => Successfully copied to the split directory
#
# Processing 065_W005
# => Successfully copied to the split directory
#
# Processing 293_W100
# => Successfully copied to the split directory
#
# Processing 257_W042
# => Successfully copied to the split directory
#
# Processing 577_W110
# => Successfully copied to the split directory
#
# Processing 473_W028
# => Successfully copied to the split directory
#
# Processing 019_W007
# => Successfully copied to the split directory
#
# Processing 266_M014
# => Successfully copied to the split directory
#
# Processing 985_W131
# => Successfully copied to the split directory
#
# Processing 476_W029
# => Successfully copied to the split directory
#
# Processing 193_W032
# => Successfully copied to the split directory
#
# Processing 440_M137
# => Successfully copied to the split directory
#
# Processing 918_W112
# => Successfully copied to the split directory
#
# Processing 835_W036
# => Successfully copied to the split directory
#
# Processing 447_M034
# => Successfully copied to the split directory
#
# Processing 610_W100
# => Successfully copied to the split directory
#
# Processing 120_W021
# => Successfully copied to the split directory
#
# Processing 451_M138
# => Successfully copied to the split directory
#
# Processing 459_W025
# => Successfully copied to the split directory
#
# Processing 641_W008
# => Successfully copied to the split directory
#
# Processing 397_W017
# => Successfully copied to the split directory
#
# Processing 335_M022
# => Successfully copied to the split directory
#
# Processing 142_W025
# => Successfully copied to the split directory
#
# Processing 901_M029
# => Successfully copied to the split directory
#
# Processing 178_W133
# => Successfully copied to the split directory
#
# Processing 057_W012
# => Successfully copied to the split directory
#
# Processing 626_M121
# => Successfully copied to the split directory
#
# Processing 482_W133
# => Successfully copied to the split directory
#
# Processing 777_M013
# => Successfully copied to the split directory
#
# Processing 650_W010
# => Successfully copied to the split directory
#
# Processing 553_W040
# => Successfully copied to the split directory
#
# Processing 252_M014
# => Successfully copied to the split directory
#
# Processing 807_M133
# => Successfully copied to the split directory
#
# Processing 902
# => Successfully copied to the split directory
#
# Processing 979
# => Successfully copied to the split directory
#
# Processing 416
# => Successfully copied to the split directory
#
# Processing 771
# => Successfully copied to the split directory
#
# Processing 876
# => Successfully copied to the split directory
#
# Processing 890
# => Successfully copied to the split directory
#
# Processing 537
# => Successfully copied to the split directory
#
# Processing 358
# => Successfully copied to the split directory
#
# Processing 469
# => Successfully copied to the split directory
#
# Processing 487
# => Successfully copied to the split directory
#
# Processing 017
# => Successfully copied to the split directory
#
# Processing 360
# => Successfully copied to the split directory
#
# Processing 584
# => Successfully copied to the split directory
#
# Processing 912
# => Successfully copied to the split directory
#
# Processing 024
# => Successfully copied to the split directory
#
# Processing 767
# => Successfully copied to the split directory
#
# Processing 598
# => Successfully copied to the split directory
#
# Processing 955
# => Successfully copied to the split directory
#
# Processing 707
# => Successfully copied to the split directory
#
# Processing 039
# => Successfully copied to the split directory
#
# Processing 177
# => Successfully copied to the split directory
#
# Processing 374
# => Successfully copied to the split directory
#
# Processing 582
# => Successfully copied to the split directory
#
# Processing 286
# => Successfully copied to the split directory
#
# Processing 759
# => Successfully copied to the split directory
#
# Processing 265
# => Successfully copied to the split directory
#
# Processing 218
# => Successfully copied to the split directory
#
# Processing 472
# => Successfully copied to the split directory
#
# Processing 180
# => Successfully copied to the split directory
#
# Processing 941
# => Successfully copied to the split directory
#
# Processing 885
# => Successfully copied to the split directory
#
# Processing 682
# => Successfully copied to the split directory
#
# Processing 727
# => Successfully copied to the split directory
#
# Processing 365
# => Successfully copied to the split directory
#
# Processing 836
# => Successfully copied to the split directory
#
# Processing 607
# => Successfully copied to the split directory
#
# Processing 174
# => Successfully copied to the split directory
#
# Processing 371
# => Successfully copied to the split directory
#
# Processing 065
# => Successfully copied to the split directory
#
# Processing 293
# => Successfully copied to the split directory
#
# Processing 257
# => Successfully copied to the split directory
#
# Processing 577
# => Successfully copied to the split directory
#
# Processing 473
# => Successfully copied to the split directory
#
# Processing 019
# => Successfully copied to the split directory
#
# Processing 266
# => Successfully copied to the split directory
#
# Processing 985
# => Successfully copied to the split directory
#
# Processing 476
# => Successfully copied to the split directory
#
# Processing 193
# => Successfully copied to the split directory
#
# Processing 440
# => Successfully copied to the split directory
#
# Processing 918
# => Successfully copied to the split directory
#
# Processing 835
# => Successfully copied to the split directory
#
# Processing 447
# => Successfully copied to the split directory
#
# Processing 610
# => Successfully copied to the split directory
#
# Processing 120
# => Successfully copied to the split directory
#
# Processing 451
# => Successfully copied to the split directory
#
# Processing 459
# => Successfully copied to the split directory
#
# Processing 641
# => Successfully copied to the split directory
#
# Processing 397
# => Successfully copied to the split directory
#
# Processing 335
# => Successfully copied to the split directory
#
# Processing 142
# => Successfully copied to the split directory
#
# Processing 901
# => Successfully copied to the split directory
#
# Processing 178
# => Successfully copied to the split directory
#
# Processing 057
# => Successfully copied to the split directory
#
# Processing 626
# => Successfully copied to the split directory
#
# Processing 482
# => Successfully copied to the split directory
#
# Processing 777
# => Successfully copied to the split directory
#
# Processing 650
# => Successfully copied to the split directory
#
# Processing 553
# => Successfully copied to the split directory
#
# Processing 252
# => Successfully copied to the split directory
#
# Processing 807
# => Successfully copied to the split directory
#
# Processing 083_W015
# => Successfully copied to the split directory
#
# Processing 922_M135
# => Successfully copied to the split directory
#
# Processing 454_W024
# => Successfully copied to the split directory
#
# Processing 961_W007
# => Successfully copied to the split directory
#
# Processing 629_W006
# => Successfully copied to the split directory
#
# Processing 653_M123
# => Successfully copied to the split directory
#
# Processing 741_M010
# => Successfully copied to the split directory
#
# Processing 536_W037
# => Successfully copied to the split directory
#
# Processing 923_M135
# => Successfully copied to the split directory
#
# Processing 270_M015
# => Successfully copied to the split directory
#
# Processing 083
# => Successfully copied to the split directory
#
# Processing 922
# => Successfully copied to the split directory
#
# Processing 454
# => Successfully copied to the split directory
#
# Processing 961
# => Successfully copied to the split directory
#
# Processing 629
# => Successfully copied to the split directory
#
# Processing 653
# => Successfully copied to the split directory
#
# Processing 741
# => Successfully copied to the split directory
#
# Processing 536
# => Successfully copied to the split directory
#
# Processing 923
# => Successfully copied to the split directory
#
# Processing 270
# => Successfully copied to the split directory
#
# Processing 742_M010
# => Successfully copied to the split directory
#
# Processing 008_W101
# => Successfully copied to the split directory
#
# Processing 755_M011
# => Successfully copied to the split directory
#
# Processing 054_M117
# => Successfully copied to the split directory
#
# Processing 185_M008
# => Successfully copied to the split directory
#
# Processing 121_W021
# => Successfully copied to the split directory
#
# Processing 132_W023
# => Successfully copied to the split directory
#
# Processing 163_M005
# => Successfully copied to the split directory
#
# Processing 785_W133
# => Successfully copied to the split directory
#
# Processing 651_W010
# => Successfully copied to the split directory
#
# Processing 205_W135
# => Successfully copied to the split directory
#
# Processing 645_W009
# => Successfully copied to the split directory
#
# Processing 925_M136
# => Successfully copied to the split directory
#
# Processing 188_W031
# => Successfully copied to the split directory
#
# Processing 279_M134
# => Successfully copied to the split directory
#
# Processing 543_M141
# => Successfully copied to the split directory
#
# Processing 474_W028
# => Successfully copied to the split directory
#
# Processing 698_W016
# => Successfully copied to the split directory
#
# Processing 304_M019
# => Successfully copied to the split directory
#
# Processing 695_M005
# => Successfully copied to the split directory
#
# Processing 742
# => Successfully copied to the split directory
#
# Processing 008
# => Successfully copied to the split directory
#
# Processing 755
# => Successfully copied to the split directory
#
# Processing 054
# => Successfully copied to the split directory
#
# Processing 185
# => Successfully copied to the split directory
#
# Processing 121
# => Successfully copied to the split directory
#
# Processing 132
# => Successfully copied to the split directory
#
# Processing 163
# => Successfully copied to the split directory
#
# Processing 785
# => Successfully copied to the split directory
#
# Processing 651
# => Successfully copied to the split directory
#
# Processing 205
# => Successfully copied to the split directory
#
# Processing 645
# => Successfully copied to the split directory
#
# Processing 925
# => Successfully copied to the split directory
#
# Processing 188
# => Successfully copied to the split directory
#
# Processing 279
# => Successfully copied to the split directory
#
# Processing 543
# => Successfully copied to the split directory
#
# Processing 474
# => Successfully copied to the split directory
#
# Processing 698
# => Successfully copied to the split directory
#
# Processing 304
# => Successfully copied to the split directory
#
# Processing 695
# => Successfully copied to the split directory

# %% [markdown]
# ## Create a Copy of Splitted DFDC Dataset

# %%
copy_data_to_split_dir(dfdc_split, DFDC_DIR, DFDC_OUTPUT_DIR)
# Out:
# Processing zvedcbblfc
# => Successfully copied to the split directory
#
# Processing zxjgsupwsa
# => Successfully copied to the split directory
#
# Processing ybnjvhunta
# => Successfully copied to the split directory
#
# Processing ihlbiaygvz
# => Successfully copied to the split directory
#
# Processing wiqlpmenil
# => Successfully copied to the split directory
#
# Processing tzkxumuidc
# => Successfully copied to the split directory
#
# Processing syfbyohaem
# => Successfully copied to the split directory
#
# Processing vhphtddasg
# => Successfully copied to the split directory
#
# Processing xacvqczazm
# => Successfully copied to the split directory
#
# Processing rgvpctvdkn
# => Successfully copied to the split directory
#
# Processing dxpqnkmhby
# => Successfully copied to the split directory
#
# Processing cnvhlcuyjq
# => Successfully copied to the split directory
#
# Processing zwnkaxgrub
# => Successfully copied to the split directory
#
# Processing lueanpvcqp
# => Successfully copied to the split directory
#
# Processing oxeupoccru
# => Successfully copied to the split directory
#
# Processing baoyaflncn
# => Successfully copied to the split directory
#
# Processing clfkbhcgpj
# => Successfully copied to the split directory
#
# Processing rbkxjcwygf
# => Successfully copied to the split directory
#
# Processing rtteygvedk
# => Successfully copied to the split directory
#
# Processing aeicdssqro
# => Successfully copied to the split directory
#
# Processing ryowoczves
# => Successfully copied to the split directory
#
# Processing mrerjxgkgx
# => Successfully copied to the split directory
#
# Processing fnazspfnbs
# => Successfully copied to the split directory
#
# Processing umnujcpazm
# => Successfully copied to the split directory
#
# Processing gmrpufmznq
# => Successfully copied to the split directory
#
# Processing nyhypmuqhq
# => Successfully copied to the split directory
#
# Processing ixesiknxjz
# => Successfully copied to the split directory
#
# Processing nsdfwjazft
# => Successfully copied to the split directory
#
# Processing suohhqgqsn
# => Successfully copied to the split directory
#
# Processing aumyahypue
# => Successfully copied to the split directory
#
# Processing tzzwqaxtrk
# => Successfully copied to the split directory
#
# Processing vypqvuqtiq
# => Successfully copied to the split directory
#
# Processing zuinrxdaqf
# => Successfully copied to the split directory
#
# Processing nzyjjerssg
# => Successfully copied to the split directory
#
# Processing oqgtonfnxl
# => Successfully copied to the split directory
#
# Processing ndzydaaxlz
# => Successfully copied to the split directory
#
# Processing ywkfdktsfq
# => Successfully copied to the split directory
#
# Processing jmldzfyqus
# => Successfully copied to the split directory
#
# Processing dvdiqmebgv
# => Successfully copied to the split directory
#
# Processing efzotvfgsh
# => Successfully copied to the split directory
#
# Processing ypjxnxtytu
# => Successfully copied to the split directory
#
# Processing jfcimzbqag
# => Successfully copied to the split directory
#
# Processing dffmijyodr
# => Successfully copied to the split directory
#
# Processing qeplzsixvj
# => Successfully copied to the split directory
#
# Processing gfsoiepxno
# => Successfully copied to the split directory
#
# Processing npnxvnozcs
# => Successfully copied to the split directory
#
# Processing dbmamolath
# => Successfully copied to the split directory
#
# Processing ykwcfpxysc
# => Successfully copied to the split directory
#
# Processing fmuncwjpej
# => Successfully copied to the split directory
#
# Processing pphtxhdwjf
# => Successfully copied to the split directory
#
# Processing rkanbumofm
# => Successfully copied to the split directory
#
# Processing nrkhloopau
# => Successfully copied to the split directory
#
# Processing othfbpeqyn
# => Successfully copied to the split directory
#
# Processing bwpuxeqbso
# => Successfully copied to the split directory
#
# Processing swbkiqkbaz
# => Successfully copied to the split directory
#
# Processing hngbppnrys
# => Successfully copied to the split directory
#
# Processing wfdkvfpvbe
# => Successfully copied to the split directory
#
# Processing etxenjfnaf
# => Successfully copied to the split directory
#
# Processing pcpkiaeylj
# => Successfully copied to the split directory
#
# Processing hahfniezou
# => Successfully copied to the split directory
#
# Processing danyfkofxk
# => Successfully copied to the split directory
#
# Processing aofqqeiisz
# => Successfully copied to the split directory
#
# Processing qazjesxsez
# => Successfully copied to the split directory
#
# Processing akhzndtglc
# => Successfully copied to the split directory
#
# Processing qplghdvrkz
# => Successfully copied to the split directory
#
# Processing emazlhouiw
# => Successfully copied to the split directory
#
# Processing idvdwmuiyg
# => Successfully copied to the split directory
#
# Processing zorspjgmyr
# => Successfully copied to the split directory
#
# Processing gjmpseimsk
# => Successfully copied to the split directory
#
# Processing ngygnxotbf
# => Successfully copied to the split directory
#
# Processing gaxvondfff
# => Successfully copied to the split directory
#
# Processing xmfcxuikuw
# => Successfully copied to the split directory
#
# Processing mdlwompdxe
# => Successfully copied to the split directory
#
# Processing nnhgfalqfr
# => Successfully copied to the split directory
#
# Processing aieqhlrbev
# => Successfully copied to the split directory
#
# Processing qtoctusxyk
# => Successfully copied to the split directory
#
# Processing eyguqfmgzh
# => Successfully copied to the split directory
#
# Processing rswrkccemc
# => Successfully copied to the split directory
#
# Processing bhifvlgump
# => Successfully copied to the split directory
#
# Processing ibmbevjtck
# => Successfully copied to the split directory
#
# Processing vtiwviltlz
# => Successfully copied to the split directory
#
# Processing ylcwtghrqs
# => Successfully copied to the split directory
#
# Processing aelfnikyqj
# => Successfully copied to the split directory
#
# Processing gbpymmkcbw
# => Successfully copied to the split directory
#
# Processing cozslsoswi
# => Successfully copied to the split directory
#
# Processing xqfvnauoid
# => Successfully copied to the split directory
#
# Processing ugqeuxruef
# => Successfully copied to the split directory
#
# Processing uvhxgaoieh
# => Successfully copied to the split directory
#
# Processing vdrotdezmh
# => Successfully copied to the split directory
#
# Processing oyivoexwpp
# => Successfully copied to the split directory
#
# Processing deckvbmgtn
# => Successfully copied to the split directory
#
# Processing xgbxdiqays
# => Successfully copied to the split directory
#
# Processing enneoqmjbk
# => Successfully copied to the split directory
#
# Processing nznptkguft
# => Successfully copied to the split directory
#
# Processing giqkvwisoa
# => Successfully copied to the split directory
#
# Processing xfvodbanvx
# => Successfully copied to the split directory
#
# Processing osffneskka
# => Successfully copied to the split directory
#
# Processing gpurfeajeg
# => Successfully copied to the split directory
#
# Processing hzkpbreqrt
# => Successfully copied to the split directory
#
# Processing nzpbjfippe
# => Successfully copied to the split directory
#
# Processing dbvdymdpym
# => Successfully copied to the split directory
#
# Processing tcloaxofyu
# => Successfully copied to the split directory
#
# Processing pqeggwylbx
# => Successfully copied to the split directory
#
# Processing hbcasaspdr
# => Successfully copied to the split directory
#
# Processing zdjdarpamb
# => Successfully copied to the split directory
#
# Processing mofsviqutr
# => Successfully copied to the split directory
#
# Processing wznwraryji
# => Successfully copied to the split directory
#
# Processing kgruikspbz
# => Successfully copied to the split directory
#
# Processing thqevqbxwt
# => Successfully copied to the split directory
#
# Processing topxckuyhd
# => Successfully copied to the split directory
#
# Processing rfesbewgwz
# => Successfully copied to the split directory
#
# Processing dghebukypk
# => Successfully copied to the split directory
#
# Processing qszvvljwav
# => Successfully copied to the split directory
#
# Processing icaeqxcbgp
# => Successfully copied to the split directory
#
# Processing ylxwcwhjjd
# => Successfully copied to the split directory
#
# Processing avkeqerpsc
# => Successfully copied to the split directory
#
# Processing bduhuslewa
# => Successfully copied to the split directory
#
# Processing encvnokybd
# => Successfully copied to the split directory
#
# Processing pkoadvlpga
# => Successfully copied to the split directory
#
# Processing yudfbdidar
# => Successfully copied to the split directory
#
# Processing cgqolgmapv
# => Successfully copied to the split directory
#
# Processing tjnlcylcoe
# => Successfully copied to the split directory
#
# Processing gepmsfvfrm
# => Successfully copied to the split directory
#
# Processing tkakcsqqyv
# => Successfully copied to the split directory
#
# Processing uyoghxdsym
# => Successfully copied to the split directory
#
# Processing bdnesbbphy
# => Successfully copied to the split directory
#
# Processing pftftfvqoa
# => Successfully copied to the split directory
#
# Processing jcqdpvjpph
# => Successfully copied to the split directory
#
# Processing ninnmxlimr
# => Successfully copied to the split directory
#
# Processing aatlprhwxl
# => Successfully copied to the split directory
#
# Processing rzorqxynsl
# => Successfully copied to the split directory
#
# Processing npermerlix
# => Successfully copied to the split directory
#
# Processing ovgqrnnpbl
# => Successfully copied to the split directory
#
# Processing yiobxevqad
# => Successfully copied to the split directory
#
# Processing thyoqkcvqq
# => Successfully copied to the split directory
#
# Processing annmtetkqa
# => Successfully copied to the split directory
#
# Processing wlhrjmuycr
# => Successfully copied to the split directory
#
# Processing qbazbfwwfr
# => Successfully copied to the split directory
#
# Processing gabvrvxcqc
# => Successfully copied to the split directory
#
# Processing psbxinwmzi
# => Successfully copied to the split directory
#
# Processing xwokqgizgw
# => Successfully copied to the split directory
#
# Processing gpjhljtyoq
# => Successfully copied to the split directory
#
# Processing cqdyheoqhn
# => Successfully copied to the split directory
#
# Processing cdwoinhglz
# => Successfully copied to the split directory
#
# Processing mecfiegzft
# => Successfully copied to the split directory
#
# Processing acrpacryoy
# => Successfully copied to the split directory
#
# Processing zpqoxwdgfx
# => Successfully copied to the split directory
#
# Processing bjqjyplccn
# => Successfully copied to the split directory
#
# Processing xtevltafix
# => Successfully copied to the split directory
#
# Processing nlonlegrdk
# => Successfully copied to the split directory
#
# Processing hazcvdjzyf
# => Successfully copied to the split directory
#
# Processing gcdtglsoqj
# => Successfully copied to the split directory
#
# Processing cwjguxtovt
# => Successfully copied to the split directory
#
# Processing biksijpktj
# => Successfully copied to the split directory
#
# Processing gzpyniwjiv
# => Successfully copied to the split directory
#
# Processing ixyqxcokrs
# => Successfully copied to the split directory
#
# Processing lpxbacokot
# => Successfully copied to the split directory
#
# Processing bkidieecdg
# => Successfully copied to the split directory
#
# Processing didzujjhtg
# => Successfully copied to the split directory
#
# Processing rxkfayific
# => Successfully copied to the split directory
#
# Processing fmlrikvqcc
# => Successfully copied to the split directory
#
# Processing phfanfjvia
# => Successfully copied to the split directory
#
# Processing xnaywmypvz
# => Successfully copied to the split directory
#
# Processing mpyrpicmjq
# => Successfully copied to the split directory
#
# Processing alvqhgaeeu
# => Successfully copied to the split directory
#
# Processing cubernsric
# => Successfully copied to the split directory
#
# Processing pvljjyeuyi
# => Successfully copied to the split directory
#
# Processing cbnyssjaho
# => Successfully copied to the split directory
#
# Processing xwojylnwtl
# => Successfully copied to the split directory
#
# Processing nxhlsqkxfv
# => Successfully copied to the split directory
#
# Processing gumtanuzts
# => Successfully copied to the split directory
#
# Processing rspzzovuct
# => Successfully copied to the split directory
#
# Processing vftkjmozdj
# => Successfully copied to the split directory
#
# Processing tbyrjoowsv
# => Successfully copied to the split directory
#
# Processing pbjbpxlhxy
# => Successfully copied to the split directory
#
# Processing lxgdlsvudr
# => Successfully copied to the split directory
#
# Processing ozxnjahnyo
# => Successfully copied to the split directory
#
# Processing glbriatpsy
# => Successfully copied to the split directory
#
# Processing bzwtxeifuu
# => Successfully copied to the split directory
#
# Processing yknlciphae
# => Successfully copied to the split directory
#
# Processing gplgurohus
# => Successfully copied to the split directory
#
# Processing hjzwbsmiam
# => Successfully copied to the split directory
#
# Processing qzwgkrampj
# => Successfully copied to the split directory
#
# Processing feihhdwmcu
# => Successfully copied to the split directory
#
# Processing slncbitmka
# => Successfully copied to the split directory
#
# Processing wugkgprala
# => Successfully copied to the split directory
#
# Processing ytwpcvjikh
# => Successfully copied to the split directory
#
# Processing hcnvjrbwyb
# => Successfully copied to the split directory
#
# Processing rplfdwhyya
# => Successfully copied to the split directory
#
# Processing xncqpmoabm
# => Successfully copied to the split directory
#
# Processing cojtqauazp
# => Successfully copied to the split directory
#
# Processing fxtrbrdcgo
# => Successfully copied to the split directory
#
# Processing gikmxcttwc
# => Successfully copied to the split directory
#
# Processing rmpbqeawlq
# => Successfully copied to the split directory
#
# Processing rcjxzkuxwc
# => Successfully copied to the split directory
#
# Processing meardvctul
# => Successfully copied to the split directory
#
# Processing mjzmlmeamj
# => Successfully copied to the split directory
#
# Processing wrcuqngerf
# => Successfully copied to the split directory
#
# Processing uunealgwvj
# => Successfully copied to the split directory
#
# Processing ahesnzswur
# => Successfully copied to the split directory

# %% [markdown]
# ## Generate CSV File to Store Split Information

# %%
cdf_split.to_csv("celeb-df-v2-split.csv", index=False)
df_split.to_csv("deeperforensics-1.0-split.csv", index=False)
dfdc_split.to_csv("dfdc-split.csv", index=False)
